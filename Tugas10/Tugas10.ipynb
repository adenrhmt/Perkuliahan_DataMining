# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

# %%
dataset = pd.read_excel('Dataset.xlsx')
dataset.keys()
# Out:
# Index(['Hari', 'Tanggal', 'Kegiatan', 'Curah Hujan (mm)', 'Penjualan (pcs)'], dtype='object')

# %%
dataku = pd.DataFrame(dataset)
dataku.head()
# Out:
#    Hari  Tanggal  Kegiatan  Curah Hujan (mm)  Penjualan (pcs)
# 0     2        1         0               1.4                0
# 1     3        2         1               1.2               27
# 2     4        3         1              15.2              458
# 3     5        4         1              13.4               20
# 4     6        5         1               7.7                7

# %%
X = np.asarray(dataset)
print(X)
# Out:
# [[2.000e+00 1.000e+00 0.000e+00 1.400e+00 0.000e+00]
#  [3.000e+00 2.000e+00 1.000e+00 1.200e+00 2.700e+01]
#  [4.000e+00 3.000e+00 1.000e+00 1.520e+01 4.580e+02]
#  [5.000e+00 4.000e+00 1.000e+00 1.340e+01 2.000e+01]
#  [6.000e+00 5.000e+00 1.000e+00 7.700e+00 7.000e+00]
#  [0.000e+00 6.000e+00 1.000e+00 6.000e-01 0.000e+00]
#  [1.000e+00 7.000e+00 1.000e+00 1.000e+00 4.000e+00]
#  [2.000e+00 8.000e+00 1.000e+00 0.000e+00 3.500e+02]
#  [3.000e+00 9.000e+00 1.000e+00 0.000e+00 1.000e+00]
#  [4.000e+00 1.000e+01 1.000e+00 3.200e+00 2.400e+02]
#  [5.000e+00 1.100e+01 1.000e+00 0.000e+00 1.300e+01]
#  [6.000e+00 1.200e+01 1.000e+00 6.200e+00 1.690e+02]
#  [0.000e+00 1.300e+01 0.000e+00 0.000e+00 0.000e+00]
#  [1.000e+00 1.400e+01 1.000e+00 3.720e+01 1.800e+01]
#  [2.000e+00 1.500e+01 1.000e+00 1.600e+00 1.000e+00]
#  [3.000e+00 1.600e+01 1.000e+00 1.610e+01 2.060e+02]
#  [4.000e+00 1.700e+01 1.000e+00 2.540e+01 1.000e+01]
#  [5.000e+00 1.800e+01 1.000e+00 1.980e+01 1.100e+01]
# ...

# %%
plt.scatter(X[:,1], X[:,4], label='True Position')
plt.xlabel("Tanggal")
plt.ylabel("Penjualan")
plt.title("Grafik Penyebaran")
plt.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[  3.48979592  15.65306122   0.95918367  24.93877551 284.97959184]
#  [  2.59722222  14.76388889   0.72222222   6.99166667  27.61111111]]

# %%
plt.scatter(X[:,1], X[:,4], c=kmeans.labels_, cmap='rainbow')
plt.xlabel("Tanggal")
plt.ylabel("penjualan")
plt.title("Grafik Hasil Klasterisasi")
plt.show()

# %%
plt.scatter(X[:,1], X[:,4], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,1], kmeans.cluster_centers_[:,4], color='black')
plt.xlabel("Tanggal")
plt.ylabel("Penjualan")
plt.title("Grafik Hasil Klasterisasi")
plt.show()
